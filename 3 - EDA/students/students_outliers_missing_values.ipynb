# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import missingno as msno
import warnings

import math

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("student_df.csv")

print(df.columns.tolist())
# Out:
# ['hh_person_id', 'tottr', 'hhmem', 'duration_min', 'trip_distance_miles', 'arr_time', 'dep_time', 'city_from_zip', 'mode_category', 'travel_date', 'gender', 'age', 'citizen', 'driver_license', 'transit_pass', 'car_sharing', 'employment', 'empl_status', 'disabled', 'transit_trip', 'transit_subsidy', 'walk_trips', 'bike_trips', 'student', 'school_grade', 'school_city', 'school_zipcode', 'school_mode', 'education', 'person_trips', 'toll_use', 'hov_lane', 'motor_trip', 'race', 'workday_range', 'incentive', 'vehicle_count', 'bike_count', 'residence_type', 'home_own', 'income', 'persons_count', 'worker_count', 'student_count', 'license_count', 'trip_count', 'home_city', 'vehicle_op_count', 'home_primarycity', 'WMO_code', 'temperature_2m_max (°C)', 'temperature_2m_min (°C)', 'temperature_2m_mean (°C)', 'apparent_temperature_mean (°C)', 'daylight_dur (s)', 'total_ precip (mm)', 'rain (mm)', 'snowfall (cm)', 'precip_hours (h)', 'model_year', 'body_type', 'fuel_type1', 'purchase_type', 'ownership', 'transmission', 'cylinders', 'veh_type', 'vehicle_used']

# %%
df.describe()
# Out:
#               tottr         hhmem  duration_min  trip_distance_miles  \
# count  40339.000000  40339.000000  40339.000000         40339.000000
# mean       2.549022      1.305436     18.125933             7.028644
# std        1.504862      1.316114     29.344852            39.813347
# min        1.000000      0.000000      1.000000             0.000000
# 25%        1.000000      0.000000      6.000000             0.885752
# 50%        2.000000      1.000000     12.000000             2.232717
# 75%        3.000000      2.000000     20.000000             5.390152
# max       41.000000      6.000000    930.000000          3065.151687
#
#              gender           age       citizen  driver_license  transit_pass  \
# count  40339.000000  40339.000000  40339.000000    40339.000000  40339.000000
# mean       1.504351     13.737946      1.061776        1.832470      1.832470
# std        0.499987     10.638588      0.240752        0.373453      0.373453
# min        1.000000      1.000000      1.000000        1.000000      1.000000
# 25%        1.000000      8.000000      1.000000        2.000000      2.000000
# 50%        2.000000     12.000000      1.000000        2.000000      2.000000
# 75%        2.000000     16.000000      1.000000        2.000000      2.000000
# max        2.000000     99.000000      2.000000        2.000000      2.000000
#
#         car_sharing  ...  precip_hours (h)   model_year    body_type  \
# count  40339.000000  ...      40339.000000  6833.000000  7009.000000
# mean       1.998537  ...          1.602866  2000.936631     3.321159
# std        0.038217  ...          4.273926     8.294682     2.981059
# min        1.000000  ...          0.000000  1941.000000     1.000000
# 25%        2.000000  ...          0.000000  1998.000000     1.000000
# 50%        2.000000  ...          0.000000  2002.000000     2.000000
# 75%        2.000000  ...          0.000000  2006.000000     4.000000
# max        2.000000  ...         24.000000  2013.000000    13.000000
#
#         fuel_type1  purchase_type    ownership  transmission    cylinders  \
# count  7025.000000    6997.000000  7019.000000   6651.000000  5860.000000
# mean      1.041708       1.583965     1.071235      1.172606     3.324061
# std       0.265408       0.492935     0.360958      0.399595     1.232462
# min       1.000000       1.000000     1.000000      1.000000     1.000000
# 25%       1.000000       1.000000     1.000000      1.000000     2.000000
# 50%       1.000000       2.000000     1.000000      1.000000     4.000000
# 75%       1.000000       2.000000     1.000000      1.000000     4.000000
# max       5.000000       2.000000     4.000000      3.000000     6.000000
#
#           veh_type  vehicle_used
# count  7009.000000   7047.000000
# mean      2.025967      1.382432
# std       0.289483      0.486016
# min       1.000000      1.000000
# 25%       2.000000      1.000000
# 50%       2.000000      1.000000
# 75%       2.000000      2.000000
# max       6.000000      2.000000
#
# [8 rows x 57 columns]

# %%
df['mode_category'].unique()
# Out:
# array(['Auto', 'Active Transportation', 'Transit', 'Other'], dtype=object)

# %%
# check for numeric values 
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

print("Numeric columns:")
print(numeric_columns)
# Out:
# Numeric columns:
# ['tottr', 'hhmem', 'duration_min', 'trip_distance_miles', 'gender', 'age', 'citizen', 'driver_license', 'transit_pass', 'car_sharing', 'employment', 'empl_status', 'disabled', 'transit_trip', 'transit_subsidy', 'walk_trips', 'bike_trips', 'student', 'school_grade', 'school_mode', 'education', 'person_trips', 'toll_use', 'hov_lane', 'motor_trip', 'race', 'incentive', 'vehicle_count', 'bike_count', 'residence_type', 'home_own', 'income', 'persons_count', 'worker_count', 'student_count', 'license_count', 'trip_count', 'vehicle_op_count', 'WMO_code', 'temperature_2m_max (°C)', 'temperature_2m_min (°C)', 'temperature_2m_mean (°C)', 'apparent_temperature_mean (°C)', 'daylight_dur (s)', 'total_ precip (mm)', 'rain (mm)', 'snowfall (cm)', 'precip_hours (h)', 'model_year', 'body_type', 'fuel_type1', 'purchase_type', 'ownership', 'transmission', 'cylinders', 'veh_type', 'vehicle_used']

# %%
# Filter numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

# Ensure 'mode_category' matches the specified modes
modes_to_plot = ['Auto', 'Active Transportation', 'Transit', 'Other']
df_filtered = df[df['mode_category'].isin(modes_to_plot)]

# Determine grid size
n_cols = 3
n_rows = math.ceil(len(numeric_columns) / n_cols)

# Create the plot grid
plt.figure(figsize=(n_cols * 5, n_rows * 4))

for i, feature in enumerate(numeric_columns):
    plt.subplot(n_rows, n_cols, i + 1)
    
    # Group data by numeric feature and mode to calculate counts
    grouped_data = df_filtered.groupby(['mode_category', feature]).size().reset_index(name='count')
    
    # Scatter plot for the current feature
    sns.scatterplot(
        data=grouped_data,
        x=feature,
        y='count',
        hue='mode_category',
        palette='Set2',
        alpha=0.8
    )
    
    plt.title(f'{feature} vs Count')
    plt.xlabel(feature)
    plt.ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.legend(title='Mode Category', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
plt.show()

# %%
# Check for null values in numeric columns
null_counts = df[numeric_columns].isnull().sum()

# Print columns with null values
print("Numeric columns with null or NaN values:")
print(null_counts[null_counts > 0])
# Out:
# Numeric columns with null or NaN values:
# employment          29155
# empl_status         29155
# transit_subsidy     31223
# school_mode          2028
# toll_use              195
# hov_lane             4961
# motor_trip            195
# vehicle_op_count     1266
# model_year          33506
# body_type           33330
# fuel_type1          33314
# purchase_type       33342
# ownership           33320
# transmission        33688
# cylinders           34479
# veh_type            33330
# vehicle_used        33292
# dtype: int64

# %%
df.shape[0]
# Out:
# 40339

# %%
# List of columns to check for null or NaN values
columns_to_clean = ['school_mode', 'toll_use', 'motor_trip']

# Drop rows with NaN in the specified columns
df_cleaned = df.dropna(subset=columns_to_clean)
df_filtered = df_cleaned[(df_cleaned['trip_distance_miles'] <= 900) & (df_cleaned['duration_min'] <= 600)]


# Check the result
print(f"Rows after dropping Na and null: {df_cleaned.shape[0]}")


# Check the result
print(f"Rows after dropping outliers: {df_filtered.shape[0]}")
# Out:
# Rows after dropping Na and null: 38122
# Rows after dropping outliers: 38097

# %%
# Select non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['number']).columns.tolist()

# Print the non-numeric columns
print("Non-numeric columns:")
print(non_numeric_columns)
# Out:
# Non-numeric columns:
# ['hh_person_id', 'arr_time', 'dep_time', 'city_from_zip', 'mode_category', 'travel_date', 'school_city', 'school_zipcode', 'workday_range', 'home_city', 'home_primarycity']

# %%
# Create a DataFrame with only non-numeric columns
df_non_numeric = df[non_numeric_columns]

# Display the DataFrame with non-numeric columns
df_non_numeric.head()
# Out:
#   hh_person_id  arr_time  dep_time             city_from_zip mode_category  \
# 0    1032036_3  11:30:00  11:10:00  Greater Los Angeles Area          Auto
# 1    1032036_3  11:45:00  11:31:00  Greater Los Angeles Area          Auto
# 2    1032036_3  12:00:00  11:52:00  Greater Los Angeles Area          Auto
# 3    1032036_3  15:50:00  15:30:00  Greater Los Angeles Area          Auto
# 4    1032036_4  08:35:00  08:15:00  Greater Los Angeles Area          Auto
#
#   travel_date school_city school_zipcode                        workday_range  \
# 0  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 1  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 2  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 3  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 4  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
#
#    home_city home_primarycity
# 0  SAN DIEGO        SAN DIEGO
# 1  SAN DIEGO        SAN DIEGO
# 2  SAN DIEGO        SAN DIEGO
# 3  SAN DIEGO        SAN DIEGO
# 4  SAN DIEGO        SAN DIEGO

# %%
# Check the data type of each column
column_types = df_non_numeric.dtypes

# Display the types
print("Data types of each column:")
print(column_types)
# Out:
# Data types of each column:
# hh_person_id        object
# arr_time            object
# dep_time            object
# city_from_zip       object
# mode_category       object
# travel_date         object
# school_city         object
# school_zipcode      object
# workday_range       object
# home_city           object
# home_primarycity    object
# dtype: object

# %%
# Convert 'dep_time' to datetime format
df['dep_time'] = pd.to_datetime(df['dep_time'], errors='coerce')

# Filter out rows where 'dep_time' could not be converted (NaT values)
df_filtered = df.dropna(subset=['dep_time'])

# Group by 'dep_time' and 'mode_category' to get the counts
grouped_data = df_filtered.groupby([df['dep_time'].dt.hour, 'mode_category']).size().reset_index(name='count')

# Plotting the count of each departure time, color-coded by mode category
plt.figure(figsize=(10, 6))
sns.scatterplot(data=grouped_data, x='dep_time', y='count', hue='mode_category', palette='Set2', alpha=0.8)

# Customize the plot
plt.title('Count of Each Departure Time by Mode Category')
plt.xlabel('Departure Time (Hour)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Mode Category')
plt.tight_layout()

plt.show()

# %% [markdown]
# # Temporal Features EDA

# %% [markdown]
# # Socio-demographics Features EDA

# %% [markdown]
# # Geospatial Features EDA

# %%
df_non_numeric.head()
# Out:
#   hh_person_id  arr_time  dep_time             city_from_zip mode_category  \
# 0    1032036_3  11:30:00  11:10:00  Greater Los Angeles Area          Auto
# 1    1032036_3  11:45:00  11:31:00  Greater Los Angeles Area          Auto
# 2    1032036_3  12:00:00  11:52:00  Greater Los Angeles Area          Auto
# 3    1032036_3  15:50:00  15:30:00  Greater Los Angeles Area          Auto
# 4    1032036_4  08:35:00  08:15:00  Greater Los Angeles Area          Auto
#
#   travel_date school_city school_zipcode                        workday_range  \
# 0  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 1  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 2  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 3  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
# 4  2012-05-12   SAN DIEGO        92127.0  [nan, nan, nan, nan, nan, nan, nan]
#
#    home_city home_primarycity
# 0  SAN DIEGO        SAN DIEGO
# 1  SAN DIEGO        SAN DIEGO
# 2  SAN DIEGO        SAN DIEGO
# 3  SAN DIEGO        SAN DIEGO
# 4  SAN DIEGO        SAN DIEGO

# %%
df_non_numeric['home_city'].unique()
# Out:
# array(['SAN DIEGO', 'ELK GROVE', 'LOS ANGELES', 'LONG BEACH', 'MILLBRAE',
#        'WILMINGTON', 'MONTCLAIR', 'REDWOOD CITY', 'SAN FRANCISCO',
#        'SANTA ANA', 'MODESTO', 'FONTANA', 'IRVINE', 'CHULA VISTA',
#        'DALY CITY', 'SANTA ROSA', 'BIXBY KNOLLS', 'STOCKTON', 'WHEATLAND',
#        'WALNUT CREEK', 'SAN LEANDRO', 'COSTA MESA', 'SEAL BEACH',
#        'FOUNTAIN VALLEY', 'PALO ALTO', 'SAN MARCOS', 'HOLLISTER',
#        'TEMECULA', 'LADERA RANCH', 'PORTOLA VALLEY', 'ESCONDIDO',
#        'OAK PARK', 'THOUSAND PALMS', 'RIO LINDA', 'THOUSAND OAKS',
#        'SACRAMENTO', 'ROCKLIN', 'RIALTO', 'LA MESA', 'FORT IRWIN',
#        'FRESNO', 'BOULDER CREEK', 'MOUNTAIN VIEW', 'ANAHEIM',
#        'SANTA CRUZ', 'SANTA CLARA', 'SUNNYVALE', 'NEWBURY PARK',
#        'SAN RAMON', 'WILLITS', 'SAN JOSE', 'BRENTWOOD', 'TUSTIN',
#        'SAN MATEO', 'MURPHYS', 'YUCAIPA', 'ROMOLAND', 'SAN BERNARDINO',
#        'GRANITE BAY', 'STANFORD', 'BAYSIDE', 'COACHELLA', 'SAN CLEMENTE',
#        'MEADOW VISTA', 'LOS GATOS', 'WESTLAKE VILLAGE', 'ATASCADERO',
#        'NEWARK', 'FORT BRAGG', 'IMPERIAL BEACH', 'VICTORVILLE',
#        'GROVELAND', 'PLEASANTON', 'OAKLAND', 'SEBASTOPOL', 'ROSEVILLE',
#        'S SAN FRANCISCO', 'ORANGE', 'ALHAMBRA', 'DAVENPORT',
#        'BAKERSFIELD', 'HEALDSBURG', 'PORTERVILLE', 'VISALIA', 'INDIO',
#        'CAMINO', 'ALAMEDA', 'VACAVILLE', 'RANCHO CUCAMONGA', 'DAVIS',
#        'NAPA', 'FAIRFIELD', 'EL MONTE', 'TRACY', 'RANCHO CORDOVA',
#        'LEMOORE', 'RIVERSIDE', 'MISSION VIEJO', 'GLENDORA', 'DIXON',
#        'ENCINITAS', 'SUISUN CITY', 'SUN CITY', 'APPLE VALLEY', 'REDLANDS',
#        'PASADENA', 'OXNARD', 'JAMESTOWN', 'AVENAL', 'TRABUCO CANYON',
#        'CATHEDRAL CITY', 'LA JOLLA', 'WEST COVINA', 'RIPON', 'PACIFICA',
#        'MIDDLETOWN', 'CHINO HILLS', 'SONORA', 'VALLEY SPRINGS',
#        'IMPERIAL', 'OCEANSIDE', 'THERMAL', 'HIGHLAND', 'WOODLAND',
#        'CYPRESS', 'POWAY', 'EL CAJON', 'HEMET', 'EL DORADO HILLS',
#        'FREMONT', 'CAMPBELL', 'VALLEJO', 'ALISO VIEJO', 'CHICO',
#        'GARDENA', 'HUNTINGTON BEACH', 'BENICIA', 'PANORAMA CITY',
#        'WILDOMAR', 'SAN PABLO', 'NORTHRIDGE', 'LAGUNA WOODS',
#        'MORENO VALLEY', 'FOSTER CITY', 'PERRIS', 'HAYWARD',
#        'SCOTTS VALLEY', 'BREA', 'TUOLUMNE', 'CLOVERDALE', 'SAN CARLOS',
#        'LAGUNA HILLS', 'TULARE', 'TWAIN HARTE', 'GRAND TERRACE', 'CERES',
#        'CUPERTINO', 'GLENDALE', 'LAGUNA NIGUEL', 'VALLEY VILLAGE',
#        'CORONA', 'MENTONE', 'WINTON', 'WALNUT', 'UPLAND', 'PLACERVILLE',
#        'EL CENTRO', 'PLACENTIA', 'BURLINGAME', 'PIEDMONT', 'MILL VALLEY',
#        'BERKELEY', 'CALEXICO', 'MARIPOSA', 'ARVIN', 'OLIVEHURST',
#        'MERCED', 'CHINO', 'LIVERMORE', 'COPPEROPOLIS', 'MORAGA', 'ORINDA',
#        'SHINGLE SPRINGS', 'SQUAW VALLEY', 'BRAWLEY', 'EAGLE ROCK',
#        'W HOLLYWOOD', 'COMPTON', 'REDONDO BEACH', 'INGLEWOOD',
#        'SANTA MONICA', 'TORRANCE', 'LA MIRADA', 'SOUTH PASADENA',
#        'TUJUNGA', 'ENCINO', 'SAN GABRIEL', 'COARSEGOLD', 'MADERA',
#        'ATWATER', 'AMERICAN CANYON', 'LAKE FOREST', 'GARDEN GROVE',
#        'SAN JACINTO', 'NATIONAL CITY', 'RAMONA', 'ROHNERT PARK',
#        'TURLOCK', 'MOORPARK', 'BEVERLY HILLS', 'HACIENDA HEIGHTS',
#        'STEVENSON RANCH', 'ONTARIO', 'WATSONVILLE', 'HESPERIA', 'ANTIOCH',
#        'SAN RAFAEL', 'LOS ALTOS', 'ANTELOPE', 'PLEASANT HILL', 'BELL',
#        'BURBANK', 'SUNLAND', 'SANTA CLARITA', 'UKIAH', 'CONCORD',
#        'VENTURA', 'REEDLEY', 'FARMERSVILLE', 'WHITTIER', 'HOLTVILLE',
#        'LA PUENTE', 'ALBANY', 'YORBA LINDA', 'WEST HILLS', 'OAKLEY',
#        'CARMICHAEL', 'CARLSBAD', 'FOLSOM', 'CANYON COUNTRY', 'FREEDOM',
#        'LA CANADA FLT', 'LAKESIDE', 'HUNTINGTON PARK',
#        'LA CRESCENTA-MONTROS', 'BALDWIN PARK', 'ADELANTO', 'SHAFTER',
#        'PITTSBURG', 'HOMELAND', 'MILPITAS', 'CERRITOS', 'DELHI',
#        'WATERFORD', 'ARCADIA', 'GILROY', 'RANCHO SANTA MARGARITA',
#        'LA HABRA', 'RANCHO PALOS VERDES', 'OROSI', 'LAKE ELSINORE',
#        'BARSTOW', 'DESERT HOT SPRINGS', 'CITRUS HEIGHTS', 'COLTON',
#        'MURRIETA', 'SOQUEL', 'SELMA', 'CULVER CITY', 'WINDSOR', 'MANTECA',
#        'ACAMPO', 'MORGAN HILL', 'CLOVIS', 'ALTADENA', 'GOLD RIVER',
#        'KENSINGTON', 'WINTERHAVEN', 'FORESTHILL', 'NEWHALL', 'SUNOL',
#        'SONOMA', 'BEN LOMOND', 'SALINAS', 'BEAUMONT', 'CHATSWORTH',
#        'ALPINE', 'ORANGEVALE', 'BELLFLOWER', 'PETALUMA', 'DANVILLE',
#        'CARSON', 'MONROVIA', 'LAFAYETTE', 'HIDDEN VALLEY LAKE',
#        'SARATOGA', 'HANFORD', 'EL CERRITO', 'WASCO', 'LEIMERT PARK',
#        'DOWNEY', 'GUERNEVILLE', 'AHWAHNEE', 'YUBA CITY', 'MIRAMONTE',
#        'SAN BRUNO', 'DISCOVERY BAY', 'MARTINEZ', 'KINGSBURG', 'EXETER',
#        'RODEO', 'PORT HUENEME', 'SAN DIMAS', 'TEHACHAPI', 'PLYMOUTH',
#        'MENLO PARK', 'TRAVIS AFB', 'SAN JUAN CAPISTRANO', 'CASTRO VALLEY',
#        'HERMOSA BEACH', 'SAN MARINO', 'HERCULES', 'COVINA', 'CARMEL',
#        'LOMITA', 'W SACRAMENTO', 'CANOGA PARK', 'AGOURA HILLS',
#        'PICO RIVERA', 'DUARTE', 'GUSTINE', 'POTTER VALLEY', 'FORESTVILLE',
#        'VISTA', 'LINCOLN', 'CORCORAN', 'SUN VALLEY', 'GREENBRAE',
#        'WINTERS', 'DANA POINT', 'WOODLAND HILLS', 'FELTON', 'N HOLLYWOOD',
#        'SAN ANDREAS', 'LAKEPORT', 'EMERYVILLE', 'MECCA', 'GALT',
#        'NORTH HILLS', 'HILMAR', 'LA VERNE', 'ELVERTA', 'PENNGROVE',
#        'BELMONT', 'WILLOWS', 'LODI', 'VALENCIA', 'SANGER', 'CLAREMONT',
#        'AZUSA', 'SYLMAR', 'VINE HILL', 'LAKEWOOD', 'ARBUCKLE', 'LOOMIS',
#        'SOULSBYVILLE', 'COULTERVILLE', 'PACOIMA', 'UNION CITY', 'ALAMO',
#        'APTOS', 'WINNETKA', 'SIERRA MADRE', 'RIDGECREST', 'FULLERTON',
#        'DENAIR', 'CAMARILLO', 'SHERMAN OAKS', 'STRATHMORE', 'LINDSAY',
#        'POMONA', 'FRAZIER PARK', 'SIMI VALLEY', 'DUBLIN', 'RICHMOND',
#        'HAWTHORNE', 'S EL MONTE', 'ROWLAND HEIGHTS', 'PESCADERO',
#        'OAKDALE', 'PACIFIC GROVE', 'SAN LUIS OBISPO', 'CHOWCHILLA',
#        'NOVATO', 'VENICE', 'NEWPORT COAST', 'LYNWOOD', 'DIAMOND SPRINGS',
#        'LA QUINTA', 'FIREBAUGH', 'STANTON', 'EASTSIDE', 'STUDIO CITY',
#        'CASTAIC', 'BUENA PARK', 'SOUTH GATE', 'CARDIFF', 'CORONADO',
#        'ARLETA', 'DIAMOND BAR', 'ST HELENA', 'NORTH LONG BEACH',
#        'HALF MOON BAY', 'PARAMOUNT', 'LANCASTER', 'FALLBROOK',
#        'WINCHESTER', 'AUGUST', 'NORTH HIGHLANDS', 'SALIDA', 'TARZANA',
#        'ANZA', 'DEL REY', 'LA PALMA', 'CLAYTON', 'POLLOCK PINES',
#        'SOMERSET', 'VALLEY GLEN', 'PALM DESERT', 'NEWPORT BEACH',
#        'LOS BANOS', 'COMMERCE', 'HIGHLAND PARK', 'EL SEGUNDO',
#        'SOLANA BEACH', 'MC FARLAND', 'HARBOR CITY', 'ESCALON', 'DINUBA',
#        'MONTARA', 'MOJAVE', 'WESTMINSTER', 'ROSEMEAD', 'LINDEN',
#        'EL SOBRANTE', 'MENIFEE', 'NORCO', 'CANYON LAKE', 'S PASADENA',
#        'PLACER', 'PIONEER', 'DELANO', 'WARNER SPRINGS', 'PINE GROVE',
#        'GRATON', 'HEBER', 'MANHATTAN BEACH', 'LAWNDALE', 'LEMON COVE',
#        'RESCUE', 'LOS ALAMITOS', 'RESEDA', 'HUGHSON', 'JAMUL',
#        'MONTEREY PARK', 'KERMAN', 'MIDPINES', 'GRANADA HILLS',
#        'SANTA BARBARA', 'MONTROSE', 'ELK', 'CALISTOGA', 'POINT LOMA',
#        'MIDWAY CITY', 'SAN FERNANDO', 'FOOTHILL RANCH', 'SANTA MARIA',
#        'EMERALD HILLS', 'LIVINGSTON', 'PATTERSON', 'SANTEE',
#        'SAN JUAN BAUTISTA', 'EL NIDO', 'CARUTHERS', 'SANTA PAULA',
#        'BLOOMINGTON', 'JACKSON', 'SAN ANSELMO', 'CASTROVILLE',
#        'BIG BEAR CITY', 'NORWALK', 'GUALALA', 'GLEN ELLEN', 'VILLA PARK',
#        'AUBURN', 'MARINA DEL REY', 'BLYTHE', 'HILLSBOROUGH',
#        'PLUMAS LAKE', 'SHADOW HILLS', 'TWENTYNINE PALMS',
#        'MOUNTAIN RANCH', 'PALMDALE', 'COLUMBIA', 'KING CITY', 'COLFAX',
#        'SAN PEDRO', 'ESPARTO', 'PALM SPRINGS', 'VAN NUYS', 'TAFT',
#        'GRASS VALLEY', 'MALIBU', 'LAGUNA BEACH', 'ACTON', 'LATHROP',
#        'WESTCHESTER', 'COVELO', 'CAPITOLA', 'GEORGETOWN', 'LOCKEFORD',
#        'BISHOP', 'RIVERBANK', 'LAMONT', 'REDDING', 'CONTRA COSTA CENTRE ',
#        'TEMPLE CITY', 'REDWOOD VALLEY', 'LEMON GROVE', 'DEL MAR',
#        'SAN LORENZO', 'SIGNAL HILL', 'AROMAS', 'CALABASAS', 'BANNING',
#        'ATHERTON', 'WRIGHTWOOD', 'FRIANT', 'FAIR OAKS', 'CAMERON PARK',
#        'BELL GARDENS', 'CAMPO', 'MAYWOOD', 'ROYAL OAKS', 'EASTVALE',
#        'CLEARLAKE', 'ROSAMOND', 'BROWNSVILLE', 'GARDEN VALLEY',
#        'LIVE OAK', 'PALOS VERDES ESTATES', 'CAZADERO', 'VIOLA',
#        'MONTEBELLO', 'ALTA LOMA', 'KETTLEMAN CITY', 'THREE RIVERS',
#        'MID-CITY', 'BALDWIN HILLS', 'PINOLE', 'ANGWIN', 'RIO VISTA',
#        'PENRYN', 'YUCCA VALLEY', 'PACHECO', 'HAWAIIAN GARDENS', 'BONSALL',
#        'PHELAN', 'MOSS BEACH', 'WATTS', 'CALIMESA', 'NUEVO',
#        'PACIFIC PALISADES', 'STRATFORD', 'VALLE VISTA', 'EL GRANADA',
#        'BODFISH', 'SPRING VALLEY', 'NEWCASTLE', 'KENTFIELD', 'TOPANGA',
#        'MARINA', 'LATON', 'BYRON', 'PINON HILLS', 'RIPLEY', 'ARTESIA',
#        'DOWNTOWN', 'WEST SIDE', 'LA PRESA', 'JOSHUA TREE',
#        'BIG BEAR LAKE', 'CRESTLINE', 'HELENDALE', 'RUNNING SPRINGS',
#        'AGUANGA', 'SILVERADO', 'PIRU', 'ARMONA', 'COALINGA', 'EARLIMART',
#        'PINE MTN CLB', 'LAKE ISABELLA', 'LEBEC', 'PIXLEY', 'SPRINGVILLE',
#        'TERRA BELLA', 'WOODLAKE', 'SAN ARDO', 'CALIFORNIA CITY',
#        'MAMMOTH LAKES', 'BASS LAKE', 'DOS PALOS', 'OAKHURST',
#        'ORANGE COVE', 'PARLIER', 'SAN JOAQUIN', 'TOLLHOUSE', 'MONTEREY',
#        'SOLEDAD', 'PAICINES', 'SAN MARTIN', 'ARNOLD', 'EL PORTAL',
#        'KEYES', 'NEWMAN', 'WESTLEY', 'YOSEMITE', 'CLEARLAKE OAKS', 'COBB',
#        'KELSEYVILLE', 'NICE', 'UPPER LAKE', 'IONE', 'SUTTER CREEK',
#        'VOLCANO', 'MARYSVILLE', 'ORLAND', 'WILLIAMS', 'CALIPATRIA',
#        'COLMA', 'HOLLYWOOD', 'CUDAHY', 'TOPANGA CANYON', 'PORTER RANCH',
#        'RANCHO MIRAGE', 'OAK HILLS', 'LUCERNE VALLEY', 'SAN JUAN CAPO',
#        'WOODSIDE', 'BAY POINT', 'S LAKE TAHOE', 'HOMEWOOD'], dtype=object)

# %%
df_non_numeric['city_from_zip'].unique()
# Out:
# array(['Greater Los Angeles Area', 'Sacramento Area',
#        'San Francisco Bay Area', 'Stockton Area', 'San Diego County',
#        'Riverside-San Bernardino', 'Fresno Area', 'Bakersfield Area'],
#       dtype=object)

# %%
# Group by 'home_city' and 'mode_category' to get counts
home_city_mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(data=home_city_mode_counts, x='city_from_zip', y='count', hue='mode_category', palette='Set2')

# Customize the plot
plt.title('Count of Modes by Home City')
plt.xlabel('Home City')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Mode Category')
plt.tight_layout()

plt.show()

# %%
import folium
from folium import Circle
from folium.plugins import HeatMap

# %%
# Calculate mode counts by city_from_zip
mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Coordinates for the centers of the mentioned areas (approximations)
area_centers = {
    'Greater Los Angeles Area': (34.0522, -118.2437),
    'Sacramento Area': (38.5816, -121.4944),
    'San Francisco Bay Area': (37.7749, -122.4194),
    'Stockton Area': (37.9577, -121.2908),
    'San Diego County': (32.7157, -117.1611),
    'Riverside-San Bernardino': (34.0522, -117.2437),
    'Fresno Area': (36.7378, -119.7871),
    'Bakersfield Area': (35.3733, -119.0187),
}

# Create the map centered around California
map_center = (36.7783, -119.4179)
m = folium.Map(location=map_center, zoom_start=6)

# Add markers for each area, color-coded by mode category
for area, coords in area_centers.items():
    area_modes = mode_counts[mode_counts['city_from_zip'] == area]
    
    # For simplicity, we are color-coding by mode_category, you can modify this based on the logic you want
    for _, row in area_modes.iterrows():
        mode = row['mode_category']
        count = row['count']
        
        # Set color based on the mode (you can customize the colors)
        mode_colors = {
            'Auto': 'yellow',
            'Transit': 'green',
            'Active Transportation': 'orange',
            'Other': 'red'
        }
        
        # Add a circle marker with color based on the mode
        folium.CircleMarker(
            location=coords,
            radius=count / 150,  # Adjust size based on count (you can modify this factor)
            color=mode_colors.get(mode, 'gray'),
            fill=True,
            fill_color=mode_colors.get(mode, 'gray'),
            fill_opacity=0.5,
            popup=f'{area}: {mode} ({count})'
        ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_86648934c507a132c1b8b4d00a7ae6bc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_86648934c507a132c1b8b4d00a7ae6bc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_86648934c507a132c1b8b4d00a7ae6bc = L.map(
#                 &quot;map_86648934c507a132c1b8b4d00a7ae6bc&quot;,
#                 {
#                     center: [36.7783, -119.4179],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a5f6bad7d2c323b8a5e58f3a832808f7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_a5f6bad7d2c323b8a5e58f3a832808f7.addTo(map_86648934c507a132c1b8b4d00a7ae6bc);
#
#
#             var circle_marker_488056de8ef5ae0712a9cadfebdb1e2e = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 19.553333333333335, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86648934c507a132c1b8b4d00a7ae6bc);
#
#
#         var popup_f00239065318506899b8fddc20e5cc20 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_b94216aa11e05c03045c9343c5894128 = $(`&lt;div id=&quot;html_b94216aa11e05c03045c9343c5894128&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Active Transportation (2933)&lt;/div&gt;`)[0];
#                 popup_f00239065318506899b8fddc20e5cc20.setContent(html_b94216aa11e05c03045c9343c5894128);
#
#
#
#         circle_marker_488056de8ef5ae0712a9cadfebdb1e2e.bindPopup(popup_f00239065318506899b8fddc20e5cc20)
#         ;
#
#
#
#
#             var circle_marker_24b960326c53aeaaf73e4e0848d139f7 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 89.90666666666667, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86648934c507a132c1b8b4d00a7ae6bc);
#
#
#         var popup_8e3fcfe82e7c0857a37f74b01ef54c9b = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_5a50e007be65f4a78eba30629da964ca = $(`&lt;div id=&quot;html_5a50e007be65f4a78eba30629da964ca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Auto (13486)&lt;/div&gt;`)[0];
#                 popup_8e3fcfe82e7c0857a37f74b01ef54c9b.setContent(html_5a50e007be65f4a78eba30629da964ca);
#
#
#
#         circle_marker_24b960326c53aeaaf73e4e0848d139f7.bindPopup(popup_8e3fcfe82e7c0857a37f74b01ef54c9b)
#         ;
#
#
#
#
#             var circle_marker_b3269cabd25c9a750d6bd1999255e9b0 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 0.38, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_86648934c507a132c1b8b4d00a7ae6bc);
#
#
#         var popup_639a99c77159e8b5900da424267bf4db = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_2119ecb82f94f7920b1a1ebe8f93195d = $(`&lt;div id=&quot;html_2119ecb82f94f7920b1a1ebe8f93195d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Other (57)&lt;/div&gt;`)[0];
#                 popup_639a99c77159e8b5900da424267bf4db.setContent(html_2119ecb82f94f7920b1a1ebe8f93195d);
#
#
#
#         circle_marker_b3269cabd25c9a750d6bd1999255e9b0.bindPopup(popup_639a99c77159e8b5900da424267bf4db)
#         ;
#
#
#
#
#             var circle_marker_77bdb3d5b99dba502a726ee645fdd6cb = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: n

# %%
# Calculate mode counts by city_from_zip
mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Coordinates for the centers of the mentioned areas (approximations)
area_centers = {
    'Greater Los Angeles Area': (34.0522, -118.2437),
    'Sacramento Area': (38.5816, -121.4944),
    'San Francisco Bay Area': (37.7749, -122.4194),
    'Stockton Area': (37.9577, -121.2908),
    'San Diego County': (32.7157, -117.1611),
    'Riverside-San Bernardino': (34.0522, -117.2437),
    'Fresno Area': (36.7378, -119.7871),
    'Bakersfield Area': (35.3733, -119.0187),
}

# Mode color dictionary for heatmap
mode_colors = {
    'Auto': 'blue',
    'Transit': 'green',
    'Active Transportation': 'orange',
    'Other': 'red'
}

# Function to generate a heatmap for a specific mode
def create_heatmap_for_mode(mode):
    # Filter the mode data
    mode_data = mode_counts[mode_counts['mode_category'] == mode]
    
    # Create a map centered around California
    map_center = (36.7783, -119.4179)
    m = folium.Map(location=map_center, zoom_start=6)
    
    # Prepare data for the heatmap (latitude, longitude, intensity)
    heat_data = []
    for _, row in mode_data.iterrows():
        city = row['city_from_zip']
        count = row['count']
        coords = area_centers[city]
        
        # Add the data point (latitude, longitude, intensity)
        heat_data.append([coords[0], coords[1], count])
    
    # Add heatmap layer for this mode
    HeatMap(heat_data, min_opacity=0.3, max_val=max(mode_counts['count']), radius=25, blur=5, gradient={0: 'gray', 0.5: mode_colors[mode], 1: mode_colors[mode]}).add_to(m)
    # just print it for now 
    # Save the map to an HTML file just print it for now 
    #m.save(f"heatmap_{mode}.html")
    return m

# Generate separate maps for each mode
for mode in mode_colors.keys():
    print(mode)
    create_heatmap_for_mode(mode)
# Out:
# Auto
# Transit
# Active Transportation
# Other

# %%
create_heatmap_for_mode('Active Transportation')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e69027d4c8cc99f014a98613383c9ddd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e69027d4c8cc99f014a98613383c9ddd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e69027d4c8cc99f014a98613383c9ddd = L.map(
#                 &quot;map_e69027d4c8cc99f014a98613383c9ddd&quot;,
#                 {
#                     center: [36.7783, -119.4179],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8e77d3fa32db53835fd2e362ee84c7f5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8e77d3fa32db53835fd2e362ee84c7f5.addTo(map_e69027d4c8cc99f014a98613383c9ddd);
#
#
#             var heat_map_78e97d030a800b7ccb70c0ea79c244e3 = L.heatLayer(
#                 [[35.3733, -119.0187, 579], [36.7378, -119.7871, 249], [34.0522, -118.2437, 2933], [34.0522, -117.2437, 106], [38.5816, -121.4944, 348], [32.7157, -117.1611, 43], [37.7749, -122.4194, 2663], [37.9577, -121.2908, 288]],
#                 {&quot;blur&quot;: 5, &quot;gradient&quot;: {&quot;0&quot;: &quot;gray&quot;, &quot;0.5&quot;: &quot;orange&quot;, &quot;1&quot;: &quot;orange&quot;}, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.3, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_78e97d030a800b7ccb70c0ea79c244e3.addTo(map_e69027d4c8cc99f014a98613383c9ddd);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

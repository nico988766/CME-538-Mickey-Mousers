# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
#import missingno as msno
import warnings

import math
from sklearn import preprocessing
from sklearn.decomposition import PCA

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import RandomizedSearchCV

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')
# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("studeny_data.csv")

print(df.columns.tolist())
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 df = pd.read_csv("worker_df.csv")
#       3 print(df.columns.tolist())
#
# File c:\Users\17052\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)
#    1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File c:\Users\17052\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File c:\Users\17052\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File c:\Users\17052\anaconda3\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File c:\Users\17052\anaconda3\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'worker_df.csv'

# %%
df.describe()
# Out:
#               tottr         hhmem  duration_min  trip_distance_miles  \
# count  97460.000000  97460.000000  97460.000000         97460.000000
# mean       1.534178      0.404525     20.879663            10.293949
# std        0.979998      0.798735     29.378780            72.107934
# min        1.000000      0.000000      1.000000             0.000000
# 25%        1.000000      0.000000      7.000000             1.206320
# 50%        1.000000      0.000000     15.000000             3.312148
# 75%        2.000000      1.000000     25.000000             9.496581
# max       31.000000      5.000000   1080.000000         15815.056366
#
#              gender           age       citizen  driver_license  transit_pass  \
# count  97460.000000  97460.000000  97460.000000    97460.000000  97460.000000
# mean       1.484712     49.767689      1.174246        1.030330      1.030330
# std        0.499769     11.622484      0.379323        0.171496      0.171496
# min        1.000000     17.000000      1.000000        1.000000      1.000000
# 25%        1.000000     42.000000      1.000000        1.000000      1.000000
# 50%        1.000000     51.000000      1.000000        1.000000      1.000000
# 75%        2.000000     58.000000      1.000000        1.000000      1.000000
# max        2.000000     98.000000      2.000000        2.000000      2.000000
#
#         car_sharing  ...  precip_hours (h)    model_year     body_type  \
# count  97460.000000  ...      97460.000000  86621.000000  87582.000000
# mean       1.979181  ...          1.556998   2003.658559      2.819301
# std        0.142778  ...          4.226746      6.113258      2.415251
# min        1.000000  ...          0.000000   1930.000000      1.000000
# 25%        2.000000  ...          0.000000   2001.000000      1.000000
# 50%        2.000000  ...          0.000000   2005.000000      2.000000
# 75%        2.000000  ...          0.000000   2008.000000      4.000000
# max        2.000000  ...         24.000000   2013.000000     13.000000
#
#          fuel_type1  purchase_type     ownership  transmission     cylinders  \
# count  87800.000000   87688.000000  87747.000000  86347.000000  76758.000000
# mean       1.052654       1.419567      1.061347      1.159010      3.249902
# std        0.315320       0.493491      0.310154      0.412675      1.173634
# min        1.000000       1.000000      1.000000      1.000000      1.000000
# 25%        1.000000       1.000000      1.000000      1.000000      2.000000
# 50%        1.000000       1.000000      1.000000      1.000000      4.000000
# 75%        1.000000       2.000000      1.000000      1.000000      4.000000
# max        5.000000       2.000000      4.000000      3.000000      7.000000
#
#            veh_type  vehicle_used
# count  87488.000000  87860.000000
# mean       1.989599      1.167152
# std        0.455434      0.373114
# min        1.000000      1.000000
# 25%        2.000000      1.000000
# 50%        2.000000      1.000000
# 75%        2.000000      1.000000
# max        6.000000      2.000000
#
# [8 rows x 62 columns]

# %%
df['mode_category'].unique()
# Out:
# array(['Auto', 'Active Transportation', 'Transit', 'Other'], dtype=object)

# %%
# check for numeric values 
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

print("Numeric columns:")
print(numeric_columns)
# Out:
# Numeric columns:
# ['tottr', 'hhmem', 'duration_min', 'trip_distance_miles', 'gender', 'age', 'citizen', 'driver_license', 'transit_pass', 'car_sharing', 'employment', 'job_count', 'empl_sec_loc', 'workday_count', 'hour_per_week', 'workday_flex', 'commute_mode', 'empl_industry', 'empl_occupation', 'disabled', 'transit_trip', 'transit_subsidy', 'walk_trips', 'bike_trips', 'student', 'education', 'person_trips', 'toll_use', 'hov_lane', 'motor_trip', 'race', 'incentive', 'vehicle_count', 'bike_count', 'residence_type', 'home_own', 'income', 'persons_count', 'worker_count', 'student_count', 'license_count', 'trip_count', 'vehicle_op_count', 'WMO_code', 'temperature_2m_max (°C)', 'temperature_2m_min (°C)', 'temperature_2m_mean (°C)', 'apparent_temperature_mean (°C)', 'daylight_dur (s)', 'total_ precip (mm)', 'rain (mm)', 'snowfall (cm)', 'precip_hours (h)', 'model_year', 'body_type', 'fuel_type1', 'purchase_type', 'ownership', 'transmission', 'cylinders', 'veh_type', 'vehicle_used']

# %%
# Filter numeric columns
numeric_columns = df.select_dtypes(include=['number']).columns.tolist()

# Ensure 'mode_category' matches the specified modes
modes_to_plot = ['Auto', 'Active Transportation', 'Transit', 'Other']
df_filtered = df[df['mode_category'].isin(modes_to_plot)]

# Determine grid size
n_cols = 3
n_rows = math.ceil(len(numeric_columns) / n_cols)

# Create the plot grid
plt.figure(figsize=(n_cols * 5, n_rows * 4))

for i, feature in enumerate(numeric_columns):
    plt.subplot(n_rows, n_cols, i + 1)
    
    # Group data by numeric feature and mode to calculate counts
    grouped_data = df_filtered.groupby(['mode_category', feature]).size().reset_index(name='count')
    
    # Scatter plot for the current feature
    sns.scatterplot(
        data=grouped_data,
        x=feature,
        y='count',
        hue='mode_category',
        palette='Set2',
        alpha=0.8
    )
    
    plt.title(f'{feature} vs Count')
    plt.xlabel(feature)
    plt.ylabel('Count')

# Adjust layout
plt.tight_layout()
plt.legend(title='Mode Category', bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
plt.show()

# %%
# Check for null values in numeric columns
null_counts = df[numeric_columns].isnull().sum()

# Print columns with null values
print("Numeric columns with null or NaN values:")
print(null_counts[null_counts > 0])
# Out:
# Numeric columns with null or NaN values:
# commute_mode        14501
# transit_subsidy     72360
# toll_use              530
# hov_lane             6941
# motor_trip            530
# vehicle_op_count     2819
# model_year          10839
# body_type            9878
# fuel_type1           9660
# purchase_type        9772
# ownership            9713
# transmission        11113
# cylinders           20702
# veh_type             9972
# vehicle_used         9600
# dtype: int64

# %%
df.shape[0]
# Out:
# 97460

# %%
# List of columns to check for null or NaN values
columns_to_clean = ['toll_use', 'motor_trip']

# Drop rows with NaN in the specified columns
df_cleaned = df.dropna(subset=columns_to_clean)
df_filtered = df_cleaned[(df_cleaned['trip_distance_miles'] <= 900) & (df_cleaned['duration_min'] <= 600)]


# Check the result
print(f"Rows after dropping Na and null: {df_cleaned.shape[0]}")


# Check the result
print(f"Rows after dropping outliers: {df_filtered.shape[0]}")
# Out:
# Rows after dropping Na and null: 96930
# Rows after dropping outliers: 96854

# %%
# Select non-numeric columns
non_numeric_columns = df.select_dtypes(exclude=['number']).columns.tolist()

# Print the non-numeric columns
print("Non-numeric columns:")
print(non_numeric_columns)
# Out:
# Non-numeric columns:
# ['hh_person_id', 'arr_time', 'dep_time', 'city_from_zip', 'mode_category', 'travel_date', 'empl_zipcode', 'workday_range', 'home_city', 'home_primarycity']

# %%
# Create a DataFrame with only non-numeric columns
df_non_numeric = df[non_numeric_columns]

# Display the DataFrame with non-numeric columns
df_non_numeric.head()
# Out:
#   hh_person_id  arr_time  dep_time             city_from_zip mode_category  \
# 0    1032036_1  08:35:00  08:15:00  Greater Los Angeles Area          Auto
# 1    1032036_1  15:50:00  15:30:00  Greater Los Angeles Area          Auto
# 2    1032036_1  16:55:00  16:30:00  Greater Los Angeles Area          Auto
# 3    1032036_1  17:55:00  17:40:00  Greater Los Angeles Area          Auto
# 4    1032036_1  19:00:00  18:40:00  Greater Los Angeles Area          Auto
#
#   travel_date empl_zipcode                      workday_range  home_city  \
# 0  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 1  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 2  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 3  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 4  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
#
#   home_primarycity
# 0        SAN DIEGO
# 1        SAN DIEGO
# 2        SAN DIEGO
# 3        SAN DIEGO
# 4        SAN DIEGO

# %%
# Check the data type of each column
column_types = df_non_numeric.dtypes

# Display the types
print("Data types of each column:")
print(column_types)
# Out:
# Data types of each column:
# hh_person_id        object
# arr_time            object
# dep_time            object
# city_from_zip       object
# mode_category       object
# travel_date         object
# empl_zipcode        object
# workday_range       object
# home_city           object
# home_primarycity    object
# dtype: object

# %%
# Convert 'dep_time' to datetime format
df['dep_time'] = pd.to_datetime(df['dep_time'], errors='coerce')

# Filter out rows where 'dep_time' could not be converted (NaT values)
df_filtered = df.dropna(subset=['dep_time'])

# Group by 'dep_time' and 'mode_category' to get the counts
grouped_data = df_filtered.groupby([df['dep_time'].dt.hour, 'mode_category']).size().reset_index(name='count')

# Plotting the count of each departure time, color-coded by mode category
plt.figure(figsize=(10, 6))
sns.scatterplot(data=grouped_data, x='dep_time', y='count', hue='mode_category', palette='Set2', alpha=0.8)

# Customize the plot
plt.title('Count of Each Departure Time by Mode Category')
plt.xlabel('Departure Time (Hour)')
plt.ylabel('Count')
plt.xticks(rotation=45)
plt.legend(title='Mode Category')
plt.tight_layout()

plt.show()

# %% [markdown]
# # Temporal Features EDA

# %% [markdown]
# # Socio-demographics Features EDA

# %% [markdown]
# # Geospatial Features EDA

# %%
df_non_numeric.head()
# Out:
#   hh_person_id  arr_time  dep_time             city_from_zip mode_category  \
# 0    1032036_1  08:35:00  08:15:00  Greater Los Angeles Area          Auto
# 1    1032036_1  15:50:00  15:30:00  Greater Los Angeles Area          Auto
# 2    1032036_1  16:55:00  16:30:00  Greater Los Angeles Area          Auto
# 3    1032036_1  17:55:00  17:40:00  Greater Los Angeles Area          Auto
# 4    1032036_1  19:00:00  18:40:00  Greater Los Angeles Area          Auto
#
#   travel_date empl_zipcode                      workday_range  home_city  \
# 0  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 1  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 2  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 3  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
# 4  2012-05-12        92127  [8, nan, nan, nan, nan, nan, nan]  SAN DIEGO
#
#   home_primarycity
# 0        SAN DIEGO
# 1        SAN DIEGO
# 2        SAN DIEGO
# 3        SAN DIEGO
# 4        SAN DIEGO

# %%
df_non_numeric['home_city'].unique()
# Out:
# array(['SAN DIEGO', 'MERCED', 'SAN FRANCISCO', 'ELK GROVE', 'SACRAMENTO',
#        'LOS ANGELES', 'CARLSBAD', 'SAN JOSE', 'LONG BEACH', 'MARTINEZ',
#        'MILLBRAE', 'BERKELEY', 'WISHON', 'BRENTWOOD', 'CLAYTON',
#        'MONTCLAIR', 'REDWOOD CITY', 'THOUSAND OAKS', 'PALO ALTO',
#        'SANTA ROSA', 'BONITA', 'VALLEY CENTER', 'PALM DESERT',
#        'LIVERMORE', 'TORRANCE', 'LAKESIDE', 'DIAMOND BAR', 'RIVERSIDE',
#        'POMONA', 'NEWHALL', 'COLTON', 'TULARE', 'CHULA VISTA', 'SARATOGA',
#        'DALY CITY', 'HAYWARD', 'BAKERSFIELD', 'ONTARIO', 'MILL VALLEY',
#        'OAKLAND', 'CITRUS HEIGHTS', 'NORTHRIDGE', 'HUNTINGTON BEACH',
#        'BIXBY KNOLLS', 'COMPTON', 'VACAVILLE', 'CARMICHAEL',
#        'DISCOVERY BAY', 'WHEATLAND', 'WALNUT CREEK', 'SAN LEANDRO',
#        'SUN CITY', 'HEMET', 'COSTA MESA', 'SANTA CRUZ', 'LA PALMA',
#        'ALHAMBRA', 'FRESNO', 'SEAL BEACH', 'CLAREMONT', 'BURLINGAME',
#        'INGLEWOOD', 'VENTURA', 'SANTEE', 'ROSEVILLE', 'SAN MARCOS',
#        'HOLLISTER', 'TEMECULA', 'HIGHLAND', 'UPPER LAKE', 'RANCHO MIRAGE',
#        'SHINGLE SPRINGS', 'FOSTER CITY', 'ANAHEIM', 'LADERA RANCH',
#        'PORTOLA VALLEY', 'BANNING', 'SANTA ANA', 'ESCONDIDO',
#        'RANCHO CUCAMONGA', 'THOUSAND PALMS', 'MODESTO', 'FAIRFIELD',
#        'TURLOCK', 'TRACY', 'SCOTTS VALLEY', 'SANTA CLARA', 'RIO LINDA',
#        'SUNNYVALE', 'REDLANDS', 'ROCKLIN', 'RIALTO', 'CERES',
#        'MORENO VALLEY', 'CARSON', 'TWAIN HARTE', 'MARIPOSA', 'MIRA LOMA',
#        'BOULDER CREEK', 'HANFORD', 'MOUNTAIN VIEW', 'JACKSON', 'SONOMA',
#        'NEWBURY PARK', 'GLENDORA', 'CLOVERDALE', 'RANCHO CORDOVA',
#        'SAN RAMON', 'PLACENTIA', 'HAWTHORNE', 'OAKDALE', 'MORRO BAY',
#        'BREA', 'SONORA', 'DAVIS', 'FULLERTON', 'OROSI', 'TUSTIN',
#        'WOODLAND', 'APPLE VALLEY', 'NORTH RIDGE', 'SAN MATEO',
#        'CAMARILLO', 'FREMONT', 'MURPHYS', 'YUCAIPA', 'ROMOLAND',
#        'SAN BERNARDINO', 'GRANITE BAY', 'LODI', 'FORESTHILL', 'OJAI',
#        'STANFORD', 'MISSION VIEJO', 'BAYSIDE', 'BEAUMONT', 'SAN CLEMENTE',
#        'EXETER', 'VISALIA', 'JAMESTOWN', 'LA MESA', 'LOS ALTOS',
#        'GARDEN GROVE', 'CORONA', 'MEADOW VISTA', 'STOCKTON',
#        'WESTLAKE VILLAGE', 'CONTRA COSTA CENTRE ', 'ATASCADERO', 'NEWARK',
#        'IRVINE', 'MENLO PARK', 'S SAN FRANCISCO', 'IMPERIAL BEACH',
#        'PETALUMA', 'VICTORVILLE', 'FORT BRAGG', 'GROVELAND', 'PLEASANTON',
#        'CHOWCHILLA', 'OCCIDENTAL', 'SEBASTOPOL', 'MARYSVILLE',
#        'POTTER VALLEY', 'ORANGE', 'SUISUN CITY', 'DAVENPORT',
#        'KELSEYVILLE', 'PORTERVILLE', 'VOLCANO', 'HEALDSBURG',
#        'VALLEY SPRINGS', 'SOUTH PASADENA', 'FORESTVILLE', 'UPLAND',
#        'CARPINTERIA', 'NEWPORT BEACH', 'EL MONTE', 'OLIVEHURST',
#        'JOSHUA TREE', 'COLUMBIA', 'SHAFTER', 'ENCINITAS', 'COULTERVILLE',
#        'FELTON', 'VALLEJO', 'WATERFORD', 'PALM SPRINGS', 'CHICO',
#        'MENIFEE', 'NEWMAN', 'OXNARD', 'AUBURN', 'GRAND TERRACE',
#        'BURBANK', 'EL CAJON', 'AVENAL', 'TRABUCO CANYON', 'NAPA',
#        'SAN CARLOS', 'UKIAH', 'ROHNERT PARK', 'NATIONAL CITY',
#        'THREE RIVERS', 'RIPON', 'SANTA MONICA', 'RIO VISTA', 'MIDDLETOWN',
#        'CHINO HILLS', 'MADERA', 'GRASS VALLEY', 'PLACERVILLE',
#        'OCEANSIDE', 'CAPITOLA', 'THERMAL', 'LOS GATOS', 'CLOVIS',
#        'CULVER CITY', 'YUCCA VALLEY', 'CYPRESS', 'POWAY', 'DOWNEY',
#        'ACAMPO', 'YORBA LINDA', 'SOMERSET', 'TUOLUMNE', 'SOLANA BEACH',
#        'INDIO', 'LATHROP', 'OAK HILLS', 'PENNGROVE', 'PASADENA',
#        'EMERYVILLE', 'SALINAS', 'SAN BRUNO', 'OAKHURST', 'WATSONVILLE',
#        'EL DORADO HILLS', 'YOUNTVILLE', 'APTOS', 'GRANADA HILLS',
#        'SPRINGVILLE', 'ALISO VIEJO', 'N HOLLYWOOD', 'SIMI VALLEY',
#        'WILMINGTON', 'NOVATO', 'LEWISTON', 'DESERT HOT SPRINGS',
#        'FOUNTAIN VALLEY', 'PATTERSON', 'BENICIA', 'PANORAMA CITY',
#        'WILDOMAR', 'SAN PABLO', 'ENCINO', 'PERRIS', 'CAMPBELL', 'SELMA',
#        'SOQUEL', 'VISTA', 'LAKE ELSINORE', 'REDONDO BEACH', 'MURRIETA',
#        'NORCO', 'LAKE FOREST', 'EL SEGUNDO', 'SHERMAN OAKS',
#        'COPPEROPOLIS', 'LAGUNA HILLS', 'SAN JUAN CAPISTRANO', 'MIDPINES',
#        'MOUNTAIN CENTER', 'LYNWOOD', 'CUPERTINO', 'WEST POINT',
#        'LAGUNA NIGUEL', 'PAICINES', 'MENDOCINO', 'LAKEPORT',
#        'W HOLLYWOOD', 'MORGAN HILL', 'MENTONE', 'SHADOW HILLS', 'LINDEN',
#        'WINTON', 'WALNUT', 'FOLSOM', 'SAUSALITO', 'FONTANA', 'EL CENTRO',
#        'PIEDMONT', 'CATHEDRAL CITY', 'NEWCASTLE', 'CHATSWORTH',
#        'TEHACHAPI', 'COOL', 'ARVIN', 'SAN PEDRO', 'LINDSAY',
#        'SOULSBYVILLE', 'TERRA BELLA', 'CANYON COUNTRY', 'HESPERIA',
#        'HACIENDA HEIGHTS', 'CALISTOGA', 'RANCHO SANTA MARGARITA',
#        'WESTCHESTER', 'WEST LAKE VILLAGE', 'CHINO', 'ALAMEDA', 'DUBLIN',
#        'ANTIOCH', 'CONCORD', 'EL CERRITO', 'LAFAYETTE', 'MORAGA',
#        'ORINDA', 'RICHMOND', 'LEMOORE', 'LOWER LAKE',
#        'HIDDEN VALLEY LAKE', 'EAGLE ROCK', 'GLASSELL PARK',
#        'HERMOSA BEACH', 'MARINA DEL REY', 'LA MIRADA', 'ALTADENA',
#        'ARCADIA', 'TUJUNGA', 'LA CRESCENTA-MONTROS', 'WEST HILLS',
#        'PACOIMA', 'SYLMAR', 'VALENCIA', 'WOODLAND HILLS', 'STUDIO CITY',
#        'SAN GABRIEL', 'COARSEGOLD', 'SAN RAFAEL', 'WILLITS', 'ATWATER',
#        'PACIFIC GROVE', 'AMERICAN CANYON', 'ST HELENA', 'PENRYN',
#        'LA QUINTA', 'LOMA LINDA', 'SPRING VALLEY', 'LA JOLLA', 'RAMONA',
#        'MANTECA', 'MOORPARK', 'W SACRAMENTO', 'WINTERS', 'BEVERLY HILLS',
#        'STEVENSON RANCH', 'MONTEBELLO', 'MILPITAS', 'PLEASANT HILL',
#        'TEMPLE CITY', 'MCKINLEYVILLE', 'SUNLAND', 'PALMDALE',
#        'SANTA CLARITA', 'GLENDALE', 'CASTRO VALLEY', 'COACHELLA',
#        'REEDLEY', 'NEVADA CITY', 'DIXON', 'FARMERSVILLE', 'WHITTIER',
#        'LINCOLN', 'CORCORAN', 'POLLOCK PINES', 'RESEDA', 'HOLTVILLE',
#        'GILROY', 'ALBANY', 'FRENCH CAMP', 'BUENA PARK', 'NEEDLES',
#        'WEST COVINA', 'PACIFIC PALISADES', 'OAKLEY', 'FREEDOM',
#        'LA CANADA FLT', 'WESTMINSTER', 'HUNTINGTON PARK', 'BALDWIN PARK',
#        'PITTSBURG', 'WOODLAKE', 'GARDENA', 'LOS BANOS', 'LA HABRA',
#        'VAN NUYS', 'SOLEDAD', 'COLFAX', 'HOLLYWOOD', 'BIGGS', 'DELHI',
#        'HALF MOON BAY', 'SAN DIMAS', 'TIPTON', 'VILLA PARK',
#        'SAN JUAN CAPO', 'LAKEWOOD', 'RANCHO PALOS VERDES', 'LA PUENTE',
#        'GALT', 'MC FARLAND', 'MALIBU', 'NEWPORT COAST', 'GARBERVILLE',
#        'DANVILLE', 'GOLD RIVER', 'KENSINGTON', 'MID-CITY', 'BOULEVARD',
#        'WINTERHAVEN', 'SAN JACINTO', 'CALEXICO', 'S EL MONTE',
#        'BEN LOMOND', 'DUARTE', 'DANA POINT', 'ALPINE', 'NORTH HIGHLANDS',
#        'ORANGEVALE', 'LOS ALAMITOS', 'MONTARA', 'MONTEREY PARK',
#        'LEMON GROVE', 'MONROVIA', 'BELLFLOWER', 'DOWNTOWN', 'VALLEY GLEN',
#        'IMPERIAL', 'EL DORADO', 'PACIFICA', 'BELMONT', 'LAWNDALE',
#        'WINDSOR', 'PINOLE', 'BASS LAKE', 'VENICE', 'LOOMIS',
#        'GUERNEVILLE', 'AHWAHNEE', 'PEBBLE BEACH', 'MIRAMONTE',
#        'TOLUCA LAKE', 'RODEO', 'HERCULES', 'SAN JUAN BAUTISTA', 'BRAWLEY',
#        'IONE', 'CALABASAS', 'WINNETKA', 'PIONEER', 'PORT HUENEME',
#        'LA VERNE', 'LOS OSOS', 'MISSION HILLS', 'BELVEDERE TIBURON',
#        'AROMAS', 'UNION CITY', 'BRADLEY', 'SAN FERNANDO', 'SUTTER',
#        'MONTEREY', 'MANHATTAN BEACH', 'TAHOE CITY', 'LAGUNA BEACH',
#        'SAN MARINO', 'NORWALK', 'WASCO', 'NORTH FORK', 'ALAMO',
#        'SAN LUIS OBISPO', 'KINGSBURG', 'PLACER', 'ATHERTON',
#        'MOKELUMNE HILL', 'LOMITA', 'SEASIDE', 'AGOURA HILLS',
#        'CANOGA PARK', 'NICOLAUS', 'VALLEY VILLAGE', 'SQUAW VALLEY',
#        'SANGER', 'BARSTOW', 'ACTON', 'FOOTHILL RANCH', 'CORONA DEL MAR',
#        'SANTA BARBARA', 'GUSTINE', 'NORTH HILLS', 'MONTROSE',
#        'GLEN ELLEN', 'SUN VALLEY', 'WESTMORLAND', 'GREENBRAE',
#        'PALOS VERDES PENINSULA', 'WILLOWS', 'DEL MAR', 'PACHECO',
#        'SAN ANDREAS', 'ANTELOPE', 'LANCASTER', 'MECCA', 'LA GRANGE',
#        'COLUSA', 'DOS PALOS', 'POPE VALLEY', 'SOUTH GATE',
#        'MOUNTAIN HOUSE', 'HILMAR', 'LAKE BALBOA', 'FAIR OAKS', 'ELVERTA',
#        'WILLIAMS', 'PENN VALLEY', 'ARBUCKLE', 'EL SOBRANTE', 'YUBA CITY',
#        'VINE HILL', 'FALLBROOK', 'CERRITOS', 'BRISBANE', 'EARLIMART',
#        'LA HONDA', 'ECHO LAKE', 'SIERRA MADRE', 'COVINA', 'BLACKHAWK',
#        'RIDGECREST', 'REDDING', 'FAIRFAX', 'CROCKETT', 'DENAIR',
#        'APPLEGATE', 'STRATHMORE', 'SIGNAL HILL', 'PARADISE', 'ORLAND',
#        'FRAZIER PARK', 'LIVINGSTON', 'CALABASAS HIGHLANDS', 'SAN ANSELMO',
#        'PISMO BEACH', 'CENTURY CITY', 'ROWLAND HEIGHTS', 'RAYMOND',
#        'LIVE OAK', 'IVANHOE', 'CASTROVILLE', 'PASO ROBLES',
#        'LEISURE WORLD', 'KEENE', 'DOYLE', 'DIAMOND SPRINGS',
#        'PICO RIVERA', 'LOCKEFORD', 'AZUSA', 'STANTON', 'EASTSIDE',
#        'RED BLUFF', 'SALIDA', 'PORTER RANCH', 'EL MACERO', 'CARDIFF',
#        'OAK PARK', 'DESCANSO', 'ROYAL OAKS', 'CORONADO', 'TAFT',
#        'SAN LUIS REY', 'PARAMOUNT', 'BAY POINT', 'WINCHESTER',
#        'FISH CAMP', 'TARZANA', 'RUNNING SPRINGS', 'DUNNIGAN', 'DEL REY',
#        'CASTAIC', 'PESCADERO', 'MOSS LANDING', 'MAGALIA', 'CORTE MADERA',
#        'LAGUNA WOODS', 'CAMERON PARK', 'COMMERCE', 'HARBOR CITY',
#        'ESCALON', 'DINUBA', 'ROSEMEAD', 'TWENTYNINE PALMS', 'ARCATA',
#        'CHERRY VALLEY', 'HOMELAND', 'ESPARTO', 'RNCHO CORDOVA',
#        'S PASADENA', 'GREENWOOD', 'REDWOOD VALLEY', 'JANESVILLE',
#        'CLEARLAKE OAKS', 'ALBION', 'DELANO', 'NORTH LONG BEACH',
#        'LAKE ISABELLA', 'WARNER SPRINGS', 'KINGS BEACH', 'LONG BARN',
#        'PINE GROVE', 'GRATON', 'HUGHSON', 'FULTON', 'EUREKA', 'HEBER',
#        'ETNA', 'FELLOWS', 'S LAKE TAHOE', 'LEMON COVE', 'RESCUE',
#        'LARKSPUR', 'COTATI', 'JAMUL', 'KERMAN', 'SUTTER CREEK',
#        'OROVILLE', 'SAN MIGUEL', 'WOODBRIDGE', 'CAMINO', 'FIREBAUGH',
#        'MARINA', 'POINT LOMA', 'AUBERRY', 'MIDWAY CITY', 'PHELAN',
#        'ARROWHEAD FARMS', 'HIGHLAND PARK', 'SANTA MARIA', 'SANTA PAULA',
#        'CALIMESA', 'AUGUST', 'BROWNS VALLEY', 'EL NIDO', 'CARUTHERS',
#        'BLOOMINGTON', 'CATHEYS VALLEY', 'MOUNTAIN RANCH', 'PHILO',
#        'BIG BEAR CITY', 'ADELANTO', 'SAN YSIDRO', 'SAN MARTIN',
#        'CAPISTRANO BEACH', 'GARDEN VALLEY', 'CAMBRIA', 'PLAYA DEL REY',
#        'CLARKSBURG', 'BLYTHE', 'CRESCENT CITY', 'PLUMAS LAKE',
#        'ARROYO GRANDE', 'PLYMOUTH', 'BISHOP', 'TOPANGA', 'RIVERBANK',
#        'YOSEMITE', 'CANYON LAKE', 'ROSAMOND', 'COVELO', 'GEYSERVILLE',
#        'CAZADERO', 'GEORGETOWN', 'LEIMERT PARK', 'BELL GARDENS',
#        'BORREGO SPRINGS', 'MOSS BEACH', 'KNIGHTS LANDING', 'SAN LORENZO',
#        'HILLSBOROUGH', 'N HIGHLANDS', 'QUARTZ HILL', 'RANCHO MURIETA',
#        'WRIGHTWOOD', 'ALTA', 'NILAND', 'PORTOLA VALELY', 'BOONVILLE',
#        'EMERALD HILLS', 'MAYWOOD', 'PIRU', 'KNIGHTSEN', 'PLEASANT GROVE',
#        'EASTVALE', 'ALTA LOMA', 'PALO VERDE', 'BROWNSVILLE', 'LAMONT',
#        'PALOMAR MOUNTAIN', 'PALOS VERDES ESTATES', 'ARLETA', 'CLEARLAKE',
#        'TOLLHOUSE', 'LA PRESA', 'ANZA', 'KEYES', 'BALDWIN HILLS',
#        'AGUANGA', 'STEVINSON', 'PIXLEY', 'MANCHESTER', 'POTRERO',
#        'HAWAIIAN GARDENS', 'NAVARRO', 'WATTS', 'PINON HILLS',
#        'ORANGE COVE', 'SANTA ROSA VALLEY', 'WELDON', 'BIG PINE',
#        'STRATFORD', 'WEIMAR', 'VALLE VISTA', 'EL GRANADA', 'AVALON',
#        'ARTESIA', 'BODFISH', 'POINT REYES STATION', 'KENTFIELD', 'LATON',
#        'BYRON', 'FORT IRWIN', 'GUALALA', 'WESTMONT', 'BELL',
#        'ROLLING HILLS ESTATES', 'PLAYA VISTA', 'MARINA DL REY',
#        'WEST SIDE', 'LAKE VIEW TERRACE', 'HAROOPA VALLEY', 'PINE VALLEY',
#        'BIG BEAR LAKE', 'CRESTLINE', 'DEATH VALLEY', 'FAWNSKIN',
#        'FOREST FALLS', 'HELENDALE', 'LAKE ARROWHEAD', 'LUCERNE VALLEY',
#        'SUGARLOAF', 'YERMO', 'MUSCOY', 'IDYLLWILD-PINE COVE',
#        'CORONA DL MAR', 'EL TORO', 'SILVERADO', 'FILLMORE', 'ARMONA',
#        'COALINGA', 'PINE MOUNTAIN CLUB', 'PINE MTN CLB',
#        'LAKE OF THE WOODS', 'KERNVILLE', 'LEBEC', 'MARICOPA', 'POSEY',
#        'RICHGROVE', 'ROSEDALE', 'OILDALE', 'SAN ARDO', 'MOJAVE',
#        'CALIFORNIA CITY', 'EDWARDS', 'MAMMOTH LAKES', 'PEARBLOSSOM',
#        'FOWLER', 'PARLIER', 'PRATHER', 'RIVERDALE', 'TRANQUILLITY',
#        'CARMEL', 'SPRECKELS', 'MONTE SERENO', 'ANGELS CAMP', 'ARNOLD',
#        'BEAR VALLEY', 'DORRINGTON', 'AVERY', 'EL PORTAL', 'EMPIRE',
#        'LE GRAND', 'PLANADA', 'SNELLING', 'WESTLEY', 'LOCH LOMOND',
#        'COBB', 'NICE', 'KLAMATH', 'AMADOR CITY', 'FIDDLETOWN',
#        'PILOT HILL', 'DRYTOWN', 'GLENN', 'GRIDLEY', 'MAXWELL', 'RACKERBY',
#        'BIEBER', 'ALTURAS', 'LOYALTON', 'TAHOMA', 'CALIPATRIA', 'SEELEY',
#        'COLMA', 'CUDAHY', 'TOPANGA CANYON', 'BELL CANYON', 'BONSALL',
#        'CABAZON', 'MORONGO VALLEY', 'SALTON CITY', 'HINKLEY',
#        'TWIN PEAKS', 'WOODSIDE', 'ANGWIN', 'SUNOL', 'MOUNT HAMILTON',
#        'HOMEWOOD', 'SIERRA CITY', 'SIERRAVILLE', 'BIG BAR', 'SUSANVILLE'],
#       dtype=object)

# %%
df_non_numeric['city_from_zip'].unique()
# Out:
# array(['Greater Los Angeles Area', 'Stockton Area',
#        'San Francisco Bay Area', 'Sacramento Area', 'Fresno Area',
#        'San Diego County', 'Riverside-San Bernardino', 'Bakersfield Area'],
#       dtype=object)

# %%
# Group by 'home_city' and 'mode_category' to get counts
home_city_mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Create the plot
plt.figure(figsize=(12, 6))
sns.barplot(data=home_city_mode_counts, x='city_from_zip', y='count', hue='mode_category', palette='Set2')

# Customize the plot
plt.title('Count of Modes by Home City')
plt.xlabel('Home City')
plt.ylabel('Count')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Mode Category')
plt.tight_layout()

plt.show()

# %%
import folium
from folium import Circle
from folium.plugins import HeatMap

# %%
# Calculate mode counts by city_from_zip
mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Coordinates for the centers of the mentioned areas (approximations)
area_centers = {
    'Greater Los Angeles Area': (34.0522, -118.2437),
    'Sacramento Area': (38.5816, -121.4944),
    'San Francisco Bay Area': (37.7749, -122.4194),
    'Stockton Area': (37.9577, -121.2908),
    'San Diego County': (32.7157, -117.1611),
    'Riverside-San Bernardino': (34.0522, -117.2437),
    'Fresno Area': (36.7378, -119.7871),
    'Bakersfield Area': (35.3733, -119.0187),
}

# Create the map centered around California
map_center = (36.7783, -119.4179)
m = folium.Map(location=map_center, zoom_start=6)

# Add markers for each area, color-coded by mode category
for area, coords in area_centers.items():
    area_modes = mode_counts[mode_counts['city_from_zip'] == area]
    
    # For simplicity, we are color-coding by mode_category, you can modify this based on the logic you want
    for _, row in area_modes.iterrows():
        mode = row['mode_category']
        count = row['count']
        
        # Set color based on the mode (you can customize the colors)
        mode_colors = {
            'Auto': 'yellow',
            'Transit': 'green',
            'Active Transportation': 'orange',
            'Other': 'red'
        }
        
        # Add a circle marker with color based on the mode
        folium.CircleMarker(
            location=coords,
            radius=count / 150,  # Adjust size based on count (you can modify this factor)
            color=mode_colors.get(mode, 'gray'),
            fill=True,
            fill_color=mode_colors.get(mode, 'gray'),
            fill_opacity=0.5,
            popup=f'{area}: {mode} ({count})'
        ).add_to(m)

# Display the map
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5092594b82b65207e245f5109c5ebace {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5092594b82b65207e245f5109c5ebace&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5092594b82b65207e245f5109c5ebace = L.map(
#                 &quot;map_5092594b82b65207e245f5109c5ebace&quot;,
#                 {
#                     center: [36.7783, -119.4179],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_718a12195bb4a7cc5fa0a64e893405b4 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_718a12195bb4a7cc5fa0a64e893405b4.addTo(map_5092594b82b65207e245f5109c5ebace);
#
#
#             var circle_marker_98f3364600e323f2bcc6648c41f29438 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;orange&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;orange&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 25.953333333333333, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5092594b82b65207e245f5109c5ebace);
#
#
#         var popup_c1079de0580bdc370806559ae3cd2377 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_a729b50373be68d32e1e39bc7c1b38eb = $(`&lt;div id=&quot;html_a729b50373be68d32e1e39bc7c1b38eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Active Transportation (3893)&lt;/div&gt;`)[0];
#                 popup_c1079de0580bdc370806559ae3cd2377.setContent(html_a729b50373be68d32e1e39bc7c1b38eb);
#
#
#
#         circle_marker_98f3364600e323f2bcc6648c41f29438.bindPopup(popup_c1079de0580bdc370806559ae3cd2377)
#         ;
#
#
#
#
#             var circle_marker_7c1e94a7acb045839b6de9ce416c8b70 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;yellow&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;yellow&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 229.77333333333334, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5092594b82b65207e245f5109c5ebace);
#
#
#         var popup_aac53148f85920724a7a14a61c00609f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_d470bede262b95b2fa7af0015bcd1be0 = $(`&lt;div id=&quot;html_d470bede262b95b2fa7af0015bcd1be0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Auto (34466)&lt;/div&gt;`)[0];
#                 popup_aac53148f85920724a7a14a61c00609f.setContent(html_d470bede262b95b2fa7af0015bcd1be0);
#
#
#
#         circle_marker_7c1e94a7acb045839b6de9ce416c8b70.bindPopup(popup_aac53148f85920724a7a14a61c00609f)
#         ;
#
#
#
#
#             var circle_marker_c3bd0599676a919b09048ad272e13074 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.5, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 1.2266666666666666, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_5092594b82b65207e245f5109c5ebace);
#
#
#         var popup_6bcc5c5b6b019a245473db9e293884a2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_12a815ca9143846b2811ed1830f8dc39 = $(`&lt;div id=&quot;html_12a815ca9143846b2811ed1830f8dc39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Greater Los Angeles Area: Other (184)&lt;/div&gt;`)[0];
#                 popup_6bcc5c5b6b019a245473db9e293884a2.setContent(html_12a815ca9143846b2811ed1830f8dc39);
#
#
#
#         circle_marker_c3bd0599676a919b09048ad272e13074.bindPopup(popup_6bcc5c5b6b019a245473db9e293884a2)
#         ;
#
#
#
#
#             var circle_marker_5a73fa54c2b91a6d2e5b6a5d25af0b73 = L.circleMarker(
#                 [34.0522, -118.2437],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;da

# %%
# Calculate mode counts by city_from_zip
mode_counts = df_filtered.groupby(['city_from_zip', 'mode_category']).size().reset_index(name='count')

# Coordinates for the centers of the mentioned areas (approximations)
area_centers = {
    'Greater Los Angeles Area': (34.0522, -118.2437),
    'Sacramento Area': (38.5816, -121.4944),
    'San Francisco Bay Area': (37.7749, -122.4194),
    'Stockton Area': (37.9577, -121.2908),
    'San Diego County': (32.7157, -117.1611),
    'Riverside-San Bernardino': (34.0522, -117.2437),
    'Fresno Area': (36.7378, -119.7871),
    'Bakersfield Area': (35.3733, -119.0187),
}

# Mode color dictionary for heatmap
mode_colors = {
    'Auto': 'blue',
    'Transit': 'green',
    'Active Transportation': 'orange',
    'Other': 'red'
}

# Function to generate a heatmap for a specific mode
def create_heatmap_for_mode(mode):
    # Filter the mode data
    mode_data = mode_counts[mode_counts['mode_category'] == mode]
    
    # Create a map centered around California
    map_center = (36.7783, -119.4179)
    m = folium.Map(location=map_center, zoom_start=6)
    
    # Prepare data for the heatmap (latitude, longitude, intensity)
    heat_data = []
    for _, row in mode_data.iterrows():
        city = row['city_from_zip']
        count = row['count']
        coords = area_centers[city]
        
        # Add the data point (latitude, longitude, intensity)
        heat_data.append([coords[0], coords[1], count])
    
    # Add heatmap layer for this mode
    HeatMap(heat_data, min_opacity=0.3, max_val=max(mode_counts['count']), radius=25, blur=5, gradient={0: 'gray', 0.5: mode_colors[mode], 1: mode_colors[mode]}).add_to(m)
    # just print it for now 
    # Save the map to an HTML file just print it for now 
    #m.save(f"heatmap_{mode}.html")
    return m

# Generate separate maps for each mode
for mode in mode_colors.keys():
    print(mode)
    create_heatmap_for_mode(mode)
# Out:
# Auto
# Transit
# Active Transportation
# Other

# %%
create_heatmap_for_mode('Active Transportation')
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2c1a5f6e0ac0ad26b7d003c3a183850f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2c1a5f6e0ac0ad26b7d003c3a183850f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2c1a5f6e0ac0ad26b7d003c3a183850f = L.map(
#                 &quot;map_2c1a5f6e0ac0ad26b7d003c3a183850f&quot;,
#                 {
#                     center: [36.7783, -119.4179],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 6,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_83c88d01b3118f0fc034763982771dae = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_83c88d01b3118f0fc034763982771dae.addTo(map_2c1a5f6e0ac0ad26b7d003c3a183850f);
#
#
#             var heat_map_66de428f0e213ea395fe53693336e721 = L.heatLayer(
#                 [[35.3733, -119.0187, 342], [36.7378, -119.7871, 172], [34.0522, -118.2437, 3893], [34.0522, -117.2437, 82], [38.5816, -121.4944, 548], [32.7157, -117.1611, 32], [37.7749, -122.4194, 7112], [37.9577, -121.2908, 225]],
#                 {&quot;blur&quot;: 5, &quot;gradient&quot;: {&quot;0&quot;: &quot;gray&quot;, &quot;0.5&quot;: &quot;orange&quot;, &quot;1&quot;: &quot;orange&quot;}, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.3, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_66de428f0e213ea395fe53693336e721.addTo(map_2c1a5f6e0ac0ad26b7d003c3a183850f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# #### Feature Enginnering

# %%
# Convert 'dep_time' to datetime format
df_filtered['travel_date'] = pd.to_datetime(df_filtered['travel_date'], errors='coerce')

# %%
df_filtered['day_w'] = df_filtered['travel_date'].dt.dayofweek

# %%
df_filtered
# Out:
#       hh_person_id  tottr  hhmem  duration_min  trip_distance_miles  arr_time  \
# 0        1032036_1    3.0    2.0          20.0             3.619057  08:35:00
# 1        1032036_1    5.0    4.0          20.0             3.587950  15:50:00
# 2        1032036_1    2.0    1.0          25.0            19.351621  16:55:00
# 3        1032036_1    2.0    1.0          15.0             6.451126  17:55:00
# 4        1032036_1    2.0    1.0          20.0            17.657172  19:00:00
# ...            ...    ...    ...           ...                  ...       ...
# 97455    7211560_2    1.0    0.0           4.0             0.181507  16:02:00
# 97456    7211560_2    1.0    0.0          14.0             2.674467  16:47:00
# 97457    7211560_2    1.0    0.0          17.0             2.621383  17:25:00
# 97458    7211560_2    1.0    0.0          94.0            10.356760  19:17:00
# 97459    7211944_1    1.0    0.0          90.0            99.860675  20:00:00
#
#                  dep_time             city_from_zip          mode_category  \
# 0     2024-11-30 08:15:00  Greater Los Angeles Area                   Auto
# 1     2024-11-30 15:30:00  Greater Los Angeles Area                   Auto
# 2     2024-11-30 16:30:00  Greater Los Angeles Area                   Auto
# 3     2024-11-30 17:40:00  Greater Los Angeles Area                   Auto
# 4     2024-11-30 18:40:00  Greater Los Angeles Area                   Auto
# ...                   ...                       ...                    ...
# 97455 2024-11-30 15:58:00    San Francisco Bay Area                   Auto
# 97456 2024-11-30 16:33:00    San Francisco Bay Area                   Auto
# 97457 2024-11-30 17:08:00    San Francisco Bay Area  Active Transportation
# 97458 2024-11-30 17:43:00    San Francisco Bay Area  Active Transportation
# 97459 2024-11-30 18:30:00           Sacramento Area                   Auto
#
#       travel_date  ...  model_year  body_type  fuel_type1  purchase_type  \
# 0      2012-05-12  ...      2007.0        8.0         1.0            1.0
# 1      2012-05-12  ...      2007.0        8.0         1.0            1.0
# 2      2012-05-12  ...      2007.0        8.0         1.0            1.0
# 3      2012-05-12  ...      2007.0        8.0         1.0            1.0
# 4      2012-05-12  ...      2007.0        8.0         1.0            1.0
# ...           ...  ...         ...        ...         ...            ...
# 97455  2013-01-30  ...         NaN        NaN         NaN            NaN
# 97456  2013-01-30  ...         NaN        NaN         NaN            NaN
# 97457  2013-01-30  ...         NaN        NaN         NaN            NaN
# 97458  2013-01-30  ...         NaN        NaN         NaN            NaN
# 97459  2013-01-15  ...      2002.0        1.0         1.0            1.0
#
#        ownership  transmission  cylinders  veh_type  vehicle_used day_w
# 0            1.0           1.0        4.0       2.0           1.0     5
# 1            1.0           1.0        4.0       2.0           1.0     5
# 2            1.0           1.0        4.0       2.0           1.0     5
# 3            1.0           1.0        4.0       2.0           1.0     5
# 4            1.0           1.0        4.0       2.0           1.0     5
# ...          ...           ...        ...       ...           ...   ...
# 97455        NaN           NaN        NaN       NaN           NaN     2
# 97456        NaN           NaN        NaN       NaN           NaN     2
# 97457        NaN           NaN        NaN       NaN           NaN     2
# 97458        NaN           NaN        NaN       NaN           NaN     2
# 97459        1.0           1.0        4.0       2.0           1.0     1
#
# [97460 rows x 73 columns]

# %%
import ast

# First convert the units column into an actual list
df_filtered.loc[:, 'workday_range'] = df_filtered['workday_range'].str.strip("[]").str.replace("'", "").str.split(", ")

# Function to handle 'nan' and numbers in a string list
def convert_list_to_int_or_nan(x):
    if isinstance(x, str):
        # Convert string to list using ast.literal_eval
        x = ast.literal_eval(x)

    # Now process the list, convert numeric strings to int and 'nan' to np.nan
    result = []
    for val in x:
        if isinstance(val, str):
            # If it's a string number (e.g., '5.0', '6.0'), convert to float or int
            if val.lower() != 'nan':
                result.append(int(float(val)))  # Convert numeric string to an integer
            else:
                result.append(np.nan)  # Replace 'nan' string with np.nan
        elif isinstance(val, (float, int)):
            result.append(int(val))  # Convert numeric types to integer
        else:
            result.append(np.nan)  # Handle non-numeric values

    return result

# Apply this function to the 'workday_range' column
df_filtered.loc[:, 'workday_range'] = df_filtered['workday_range'].apply(convert_list_to_int_or_nan)

# %%
def check_workday(travel_date, workday_range):
    # If the person works Monday to Friday (8)
    if 8 in workday_range:
        if travel_date == 5 or travel_date == 6:  # Saturday (5) or Sunday (6)
            return 2  # Not a workday
        else:
            return 1  # Monday to Friday is a workday
    # If the person works on specific days in workday_range (1-7)
    elif (travel_date + 1) in workday_range:  # Convert travel_date 0-6 to 1-7 (Monday=1, Sunday=7)
        return 1  # It is a workday
    else:
        return 2  # Not a workday

# Apply the function to the DataFrame
df_filtered['is_workday'] = df_filtered.apply(lambda row: check_workday(row['day_w'], row['workday_range']), axis=1)


# Display the updated DataFrame with the new 'is_workday' column
print(df_filtered[['day_w', 'workday_range', 'is_workday']])
# Out:
#        day_w                      workday_range  is_workday
# 0          5  [8, nan, nan, nan, nan, nan, nan]           2
# 1          5  [8, nan, nan, nan, nan, nan, nan]           2
# 2          5  [8, nan, nan, nan, nan, nan, nan]           2
# 3          5  [8, nan, nan, nan, nan, nan, nan]           2
# 4          5  [8, nan, nan, nan, nan, nan, nan]           2
# ...      ...                                ...         ...
# 97455      2  [8, nan, nan, nan, nan, nan, nan]           1
# 97456      2  [8, nan, nan, nan, nan, nan, nan]           1
# 97457      2  [8, nan, nan, nan, nan, nan, nan]           1
# 97458      2  [8, nan, nan, nan, nan, nan, nan]           1
# 97459      1  [8, nan, nan, nan, nan, nan, nan]           1
#
# [97460 rows x 3 columns]

# %% [markdown]
# #### Feature Selection

# %%
def selected_feature(data):
    
    feature_selected = ['tottr',
                        'gender',
                        'race',
                        'age',
                        'incentive',
                        'vehicle_count',
                        'income',
                        'worker_count',
                        'is_workday',
                        'workday_count',
                        'driver_license',
                        'job_count',
                        'apparent_temperature_mean (°C)',
                        'WMO_code']

    selected_data = data[feature_selected]
    
    return selected_data

# %% [markdown]
# #### Train the Model

# %%
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
from collections import Counter

# Assume df is your DataFrame and 'y' is the target column

# Step 1: Split the data into train (70%) and temp (30%)
train_df, temp_df = train_test_split(df_filtered, test_size=0.3, stratify=df['mode_category'], random_state=42)

# Step 2: Split the temp set into validation (15%) and test (15%)
val_df, test_df = train_test_split(temp_df, test_size=0.5, stratify=temp_df['mode_category'], random_state=42)

# Step 3: Separate features (X) and target (y) for the training set
X_train = selected_feature(train_df)
y_train = train_df['mode_category']

# Step 4: Apply SMOTE to the training set
smote = SMOTE(random_state=42)
X_train_resampled, y_train_resampled = smote.fit_resample(X_train, y_train)

# Step 5: Print class distribution after SMOTE
print("Class distribution before SMOTE:", Counter(y_train))
print("Class distribution after SMOTE:", Counter(y_train_resampled))

# Step 6: Separate features and target for validation and test sets
X_val = selected_feature(val_df)
y_val = val_df['mode_category']

X_test = selected_feature(test_df)
y_test = test_df['mode_category']

# Outputs
print(f"Training set size: {X_train_resampled.shape[0]}")
print(f"Validation set size: {X_val.shape[0]}")
print(f"Test set size: {X_test.shape[0]}")
# Out:
# Class distribution before SMOTE: Counter({'Auto': 57132, 'Active Transportation': 8684, 'Transit': 2113, 'Other': 293})
# Class distribution after SMOTE: Counter({'Auto': 57132, 'Other': 57132, 'Transit': 57132, 'Active Transportation': 57132})
# Training set size: 228528
# Validation set size: 14619
# Test set size: 14619

# %%
model = RandomForestClassifier(random_state=42)

# Fit and predict
model.fit(X_train_resampled, y_train_resampled)
# Out:
# RandomForestClassifier(random_state=42)

# %%
y_pred = model.predict(X_val)

# %% [markdown]
# #### Check the performance of the model

# %%
accuracy = accuracy_score(y_val, y_pred)

print(f"Accuracy of the Random Forest Classifier: {accuracy * 100:.2f}%")
# Out:
# Accuracy of the Random Forest Classifier: 88.15%

# %%
from sklearn.model_selection import cross_val_score

# Perform cross-validation
cv_scores = cross_val_score(model, X_train_resampled, y_train_resampled, cv=5)

print(f"Cross-Validated Accuracy: {cv_scores.mean() * 100:.2f}%")
# Out:
# Cross-Validated Accuracy: 91.69%

# %%
from sklearn.metrics import classification_report, f1_score

# Step 1: Check class distribution
unique, counts = np.unique(y_val, return_counts=True)
class_distribution = dict(zip(unique, counts))
print("Class Distribution:", class_distribution)

# Step 2: Generate classification report
report = classification_report(y_val, y_pred, target_names=['Active Transportation', 'Auto', 'Other', 'Transit'], digits=3)
print("\nClassification Report:\n", report)

# Step 3: Calculate weighted F1-score
weighted_f1 = f1_score(y_val, y_pred, average='weighted')
print("\nWeighted F1-Score:", weighted_f1)
# Out:
# Class Distribution: {'Active Transportation': np.int64(1861), 'Auto': np.int64(12242), 'Other': np.int64(63), 'Transit': np.int64(453)}
#
# Classification Report:
#                         precision    recall  f1-score   support
#
# Active Transportation      0.578     0.571     0.574      1861
#                  Auto      0.960     0.952     0.956     12242
#                 Other      0.375     0.333     0.353        63
#               Transit      0.253     0.327     0.285       453
#
#              accuracy                          0.881     14619
#             macro avg      0.542     0.546     0.542     14619
#          weighted avg      0.887     0.881     0.884     14619
#
#
# Weighted F1-Score: 0.8840416013093141

# %%
# Feature importances
importances = model.feature_importances_
feature_names = X_train.columns
feature_importance_df = pd.DataFrame({
    'Feature': feature_names,
    'Importance': importances
})

# Sort features by importance
feature_importance_df = feature_importance_df.sort_values(by='Importance', ascending=False)

# Display the top 10 features
print("\nTop 10 Important Features:")
print(feature_importance_df.head(10))

# Plot the top 10 feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feature_importance_df.head(10))
plt.title('Top 10 Feature Importances')
plt.tight_layout()
plt.show()
# Out:
# Top 10 Important Features:
#                            Feature  Importance
# 3                              age    0.181766
# 12  apparent_temperature_mean (°C)    0.179275
# 13                        WMO_code    0.106404
# 0                            tottr    0.096564
# 6                           income    0.080296
# 5                    vehicle_count    0.075574
# 9                    workday_count    0.068243
# 1                           gender    0.059171
# 2                             race    0.038541
# 7                     worker_count    0.030417

# %%
# Import 3rd party libraries
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Configure Notebook
# %matplotlib inline
plt.style.use('fivethirtyeight')
sns.set_context("notebook")
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# #### Open the merged dataset of the HH, PER and weather datasets.

# %%
merged_weather = pd.read_csv('merged_weather.csv')

# %% [markdown]
# #### Open the cleaned VEH dataset

# %%
clean_veh = pd.read_csv('cleaned_veh_df.csv')

# %%
# View DataFrame
clean_veh.head()
# Out:
#    Unnamed: 0  hh_veh_id  Year of vehicle  Vehicle body type  \
# 0           0  1031985_1           2006.0                1.0
# 1           1  1031985_2           1987.0                5.0
# 2           2  1032036_1           2007.0                8.0
# 3           3  1032053_1           2001.0                1.0
# 4           4  1032053_2           2003.0                2.0
#
#    Primary fuel type  Vehicle acquired  Vehicle ownership type  \
# 0                1.0               2.0                     1.0
# 1                1.0               2.0                     1.0
# 2                1.0               1.0                     1.0
# 3                1.0               2.0                     1.0
# 4                1.0               2.0                     1.0
#
#    Vehicle transmission type  Vehicle drive type  Vehicle cylinder count  \
# 0                        1.0                 2.0                     4.0
# 1                        NaN                 NaN                     NaN
# 2                        1.0                 1.0                     4.0
# 3                        1.0                 1.0                     2.0
# 4                        1.0                 3.0                     5.0
#
#    Vehicle type  was vehicle used on travel day  reason why not
# 0           2.0                               1             NaN
# 1           2.0                               2             NaN
# 2           2.0                               1             NaN
# 3           2.0                               1             NaN
# 4           2.0                               1             NaN

# %%
# Convert the 'SAMPN' from float to int
merged_weather['SAMPN'] = merged_weather['SAMPN'].astype(int)

# Convert the 'SAMPN' from float to int
merged_weather['PERNO'] = merged_weather['PERNO'].astype(int)

# Create a new column 'hh_veh_id' by merging 'SAMPN' and 'PERNO'
merged_weather['hh_veh_id'] = merged_weather['SAMPN'].astype(str) + '_' + merged_weather['PERNO'].astype(str)

# Reorder columns to make 'hh_veh_id' the first column
merged_weather = merged_weather[['hh_veh_id'] + [col for col in merged_weather.columns if col != 'hh_veh_id']]

# Drop 'SAMPN' and 'PERNO'
merged_weather = merged_weather.drop(columns=['SAMPN', 'PERNO', 'Unnamed: 0', 'ID'])

# Reorder the date to be first too
merged_weather = merged_weather[['TDATE'] + [col for col in merged_weather.columns if col != 'TDATE']]

# %%
merged_weather.head()
# Out:
#         TDATE  hh_veh_id  RELAT  GEND   AGE  AGEB  HISP  RACE1  RACE2  RACE3  \
# 0  2012-07-18  1046924_1    1.0   2.0  77.0   NaN   2.0    1.0    NaN    NaN
# 1  2012-07-18  1046924_2    2.0   1.0  77.0   NaN   2.0    1.0    NaN    NaN
# 2  2012-05-05  1047092_1    1.0   2.0  50.0   NaN   2.0    1.0    NaN    NaN
# 3  2012-05-05  1047092_2    2.0   1.0  51.0   NaN   2.0    1.0    NaN    NaN
# 4  2012-07-05  1048704_1    1.0   2.0  36.0   NaN   1.0    1.0    NaN    NaN
#
#    ...  weather_code (wmo code) temperature_2m_max (°C)  \
# 0  ...                     51.0                    24.3
# 1  ...                     51.0                    24.3
# 2  ...                      0.0                    22.2
# 3  ...                      0.0                    22.2
# 4  ...                      0.0                    26.1
#
#    temperature_2m_min (°C)  temperature_2m_mean (°C)  \
# 0                     16.2                      21.0
# 1                     16.2                      21.0
# 2                      7.6                      15.2
# 3                      7.6                      15.2
# 4                     13.7                      19.6
#
#    apparent_temperature_mean (°C)  daylight_duration (s)  \
# 0                            21.1               50522.89
# 1                            21.1               50522.89
# 2                            12.1               50133.78
# 3                            12.1               50133.78
# 4                            20.1               51642.60
#
#    precipitation_sum (mm)  rain_sum (mm)  snowfall_sum (cm)  \
# 0                     0.2            0.2                0.0
# 1                     0.2            0.2                0.0
# 2                     0.0            0.0                0.0
# 3                     0.0            0.0                0.0
# 4                     0.0            0.0                0.0
#
#    precipitation_hours (h)
# 0                      1.0
# 1                      1.0
# 2                      0.0
# 3                      0.0
# 4                      0.0
#
# [5 rows x 237 columns]

# %%
# Merge the VEH df onto the merged_weather df
merged_df_weather_veh = pd.merge(merged_weather, clean_veh, on=['hh_veh_id'], how='left')

# Rename the ID column
merged_df_weather_veh.rename(columns={'hh_veh_id': 'ID'}, inplace=True)

# Sort the DataFrame by TDATE in chronological order
merged_df_weather_veh = merged_df_weather_veh.sort_values(by='TDATE', ascending=True).reset_index(drop=True)

# %%
merged_df_weather_veh.head()
# Out:
#         TDATE         ID  RELAT  GEND   AGE  AGEB  HISP  RACE1  RACE2  RACE3  \
# 0  2012-02-01  1138101_2    9.0   1.0  61.0   NaN   2.0    1.0    NaN    NaN
# 1  2012-02-01  1120264_1    1.0   1.0  51.0   NaN   9.0   99.0    NaN    NaN
# 2  2012-02-01  1120264_2    2.0   2.0  51.0   NaN   9.0   99.0    NaN    NaN
# 3  2012-02-01  1120264_3    3.0   1.0  26.0   NaN   2.0   99.0    NaN    NaN
# 4  2012-02-01  1120296_1    1.0   2.0  58.0   NaN   1.0   97.0    NaN    NaN
#
#    ...  Vehicle body type Primary fuel type  Vehicle acquired  \
# 0  ...                NaN               NaN               NaN
# 1  ...                1.0               1.0               1.0
# 2  ...                5.0               1.0               1.0
# 3  ...                1.0               1.0               1.0
# 4  ...                NaN               NaN               NaN
#
#    Vehicle ownership type  Vehicle transmission type  Vehicle drive type  \
# 0                     NaN                        NaN                 NaN
# 1                     1.0                        1.0                 1.0
# 2                     1.0                        1.0                 2.0
# 3                     1.0                        2.0                 1.0
# 4                     NaN                        NaN                 NaN
#
#    Vehicle cylinder count  Vehicle type  was vehicle used on travel day  \
# 0                     NaN           NaN                             NaN
# 1                     2.0           2.0                             1.0
# 2                     4.0           2.0                             1.0
# 3                     2.0           2.0                             2.0
# 4                     NaN           NaN                             NaN
#
#    reason why not
# 0             NaN
# 1             NaN
# 2             NaN
# 3             2.0
# 4             NaN
#
# [5 rows x 249 columns]

# %%
# Save the new dataset
merged_df_weather_veh.to_csv('merged_weather_VEH.csv')
